# %%
import numpy as np
import pandas as pd

# %%
# Load the data
file_path=("Resources/IRL_ClassProjectData_220210.xlsx")
fairtrade_df=pd.read_excel(file_path)

fairtrade_df.head(10)
# Out:
#   Survey Number        Response ID ch_account_name gender_core  age_core  \
# 0      Survey 2  R_1NsRph9Oqxl6CnG          Farm 1         Man        30
# 1      Survey 2  R_2BlpeLG3DymUC2o          Farm 1       Woman        30
# 2      Survey 2  R_3WMv7jb7gBKEm2t          Farm 1         Man        24
# 3      Survey 2  R_2SBT3CXWOyuor1k          Farm 1         Man        58
# 4      Survey 2  R_OBEgl4lS6LpSkDL          Farm 1         Man        38
# 5      Survey 2  R_3QY8IjWLk2ZDKDs          Farm 1         Man        37
# 6      Survey 2  R_1jHPFIUCc8JCpXa          Farm 1       Woman        27
# 7      Survey 2  R_6x0zO9KWBj8KUDL          Farm 1         Man        56
# 8      Survey 2  R_cMGCFYIGxSURpzX          Farm 1       Woman        45
# 9      Survey 2  R_1q8QVbp49i6YbKB          Farm 1       Woman        28
#
#   education_level_core worker_type_core understand_contract  \
# 0    Elementary School        Permanent                 Yes
# 1            No school        Permanent                 Yes
# 2        Middle School        Permanent                 Yes
# 3    Elementary School        Permanent                 Yes
# 4        Middle School        Permanent                 Yes
# 5    Elementary School        Permanent                 Yes
# 6        Middle School        Permanent                 Yes
# 7    Elementary School        Permanent          Don't know
# 8            No school        Permanent                 Yes
# 9    Elementary School        Permanent                 Yes
#
#    entity_tenure - Months  entity_seasons  ... accident_last_year  \
# 0                   132.0             NaN  ...                 No
# 1                   108.0             NaN  ...                 No
# 2                    67.0             NaN  ...                 No
# 3                    79.0             NaN  ...                 No
# 4                   108.0             NaN  ...                 No
# 5                   108.0             NaN  ...                 No
# 6                    33.0             NaN  ...                 No
# 7                   464.0             NaN  ...                 No
# 8                    84.0             NaN  ...                 No
# 9                    84.0             NaN  ...                 No
#
#   injury_last_year covid_safety_measures_core  return_next_season_core  \
# 0              NaN             Strongly Agree                      Yes
# 1              NaN             Strongly Agree                      Yes
# 2              NaN             Strongly Agree                      Yes
# 3              NaN             Strongly Agree                      Yes
# 4              NaN             Strongly Agree                      Yes
# 5              NaN             Strongly Agree               Don't know
# 6              NaN             Strongly Agree                      Yes
# 7              NaN             Somewhat agree                      Yes
# 8              NaN             Somewhat agree                      Yes
# 9              NaN             Strongly Agree                      Yes
#
#    pressure_to_work_core  management_complaint_treatment_core  \
# 0      Strongly disagree                                  Yes
# 1      Strongly disagree        Maybe, depending on the topic
# 2      Strongly disagree        Maybe, depending on the topic
# 3      Strongly disagree        Maybe, depending on the topic
# 4      Strongly disagree        Maybe, depending on the topic
# 5      Strongly disagree                           Don't know
# 6      Strongly disagree        Maybe, depending on the topic
# 7     Agree nor disagree                           Don't know
# 8     Agree nor disagree        Maybe, depending on the topic
# 9      Strongly disagree                                  Yes
#
#   leadership_feedback_core leadership_satisfaction_core  \
# 0                       No                          NaN
# 1                       No                          NaN
# 2                       No                          NaN
# 3                       No                          NaN
# 4                       No                          NaN
# 5                       No                          NaN
# 6                       No                          NaN
# 7                       No                          NaN
# 8                       No                          NaN
# 9                       No                          NaN
#
#   factory_recommend_tf_core Unnamed: 32
# 0                         7         NaN
# 1                         8         NaN
# 2                         8         NaN
# 3                         6         NaN
# 4                         8         NaN
# 5                         8         NaN
# 6                         7         NaN
# 7               5 - Neutral         NaN
# 8                         8         NaN
# 9    10 - Extremely likely          NaN
#
# [10 rows x 33 columns]

# %%
# Change column names 
fairtrade_df.rename(columns = {'entity_tenure - Months':'entity_tenure_total_months'}, inplace = True)

# Drop columns 
fairtrade_df.drop(['Survey Number','Response ID','ch_account_name','gender_core','age_core',
                   'education_level_core','entity_seasons','work_last_season_tf','num_week_income_core_usd',
                   'num_week_income_core_mxn','weeks_per_year','income_change_core','save_money_tf_core',
                   'financial_resilience_core','unsafe_reason_ms_core','management_complaint_treatment_core',
                   'leadership_feedback_core','leadership_satisfaction_core','Unnamed: 32'], axis=1, inplace=True)

fairtrade_df.head(10)
# Out:
#   worker_type_core understand_contract  entity_tenure_total_months  \
# 0        Permanent                 Yes                       132.0
# 1        Permanent                 Yes                       108.0
# 2        Permanent                 Yes                        67.0
# 3        Permanent                 Yes                        79.0
# 4        Permanent                 Yes                       108.0
# 5        Permanent                 Yes                       108.0
# 6        Permanent                 Yes                        33.0
# 7        Permanent          Don't know                       464.0
# 8        Permanent                 Yes                        84.0
# 9        Permanent                 Yes                        84.0
#
#                  workplace_satis_core trust_leadership_core  \
# 0                  Somewhat Satisfied                   Yes
# 1                  Somewhat Satisfied                   Yes
# 2                      Very satisfied                   Yes
# 3                      Very satisfied                   Yes
# 4                      Very satisfied                   Yes
# 5                  Somewhat Satisfied                   Yes
# 6                      Very satisfied                   Yes
# 7                  Somewhat Satisfied            Don't know
# 8                      Very satisfied            Don't know
# 9  Neither satisfied nor dissatisfied                   Yes
#
#   living_wage_tf_core conditions_rate_core     safety_core accident_last_year  \
# 0                  No        Somewhat good  Strongly agree                 No
# 1                  No  Neither good or bad  Strongly agree                 No
# 2                 Yes        Somewhat good  Strongly agree                 No
# 3                 Yes        Somewhat good  Strongly agree                 No
# 4                 Yes  Neither good or bad  Strongly agree                 No
# 5                  No  Neither good or bad  Strongly agree                 No
# 6                 Yes  Neither good or bad  Strongly agree                 No
# 7                  No  Neither good or bad  Somewhat agree                 No
# 8                  No        Somewhat good  Strongly agree                 No
# 9                 Yes  Neither good or bad  Strongly agree                 No
#
#   injury_last_year covid_safety_measures_core return_next_season_core  \
# 0              NaN             Strongly Agree                     Yes
# 1              NaN             Strongly Agree                     Yes
# 2              NaN             Strongly Agree                     Yes
# 3              NaN             Strongly Agree                     Yes
# 4              NaN             Strongly Agree                     Yes
# 5              NaN             Strongly Agree              Don't know
# 6              NaN             Strongly Agree                     Yes
# 7              NaN             Somewhat agree                     Yes
# 8              NaN             Somewhat agree                     Yes
# 9              NaN             Strongly Agree                     Yes
#
#   pressure_to_work_core factory_recommend_tf_core
# 0     Strongly disagree                         7
# 1     Strongly disagree                         8
# 2     Strongly disagree                         8
# 3     Strongly disagree                         6
# 4     Strongly disagree                         8
# 5     Strongly disagree                         8
# 6     Strongly disagree                         7
# 7    Agree nor disagree               5 - Neutral
# 8    Agree nor disagree                         8
# 9     Strongly disagree    10 - Extremely likely

# %%
# Drop rows that contain  refused or don't know

values=["Refused", "Don't know"]
fairtrade_df=fairtrade_df[fairtrade_df.factory_recommend_tf_core.isin(values)==False]

# Change string values into numbers in factory_recommend_tf_core
dict= {"10 - Extremely likely ": "10", "0- Extremely unlikely": "0", "5 - Neutral": "5"}
fairtrade_df=fairtrade_df.replace({"factory_recommend_tf_core": dict})
fairtrade_df.reset_index(inplace=True, drop=True)

fairtrade_df.head(45)
# Out:
#          worker_type_core understand_contract  entity_tenure_total_months  \
# 0               Permanent                 Yes                       132.0
# 1               Permanent                 Yes                       108.0
# 2               Permanent                 Yes                        67.0
# 3               Permanent                 Yes                        79.0
# 4               Permanent                 Yes                       108.0
# 5               Permanent                 Yes                       108.0
# 6               Permanent                 Yes                        33.0
# 7               Permanent          Don't know                       464.0
# 8               Permanent                 Yes                        84.0
# 9               Permanent                 Yes                        84.0
# 10              Permanent                 Yes                        24.0
# 11              Permanent                 Yes                        28.0
# 12              Permanent                  No                        30.0
# 13              Permanent                 Yes                        72.0
# 14             Don't know                  No                         2.0
# 15              Permanent                 Yes                        30.0
# 16              Permanent                 Yes                        72.0
# 17              Permanent                 Yes                        30.0
# 18              Permanent          Don't know                        24.0
# 19              Permanent                 Yes                        14.0
# 20              Permanent          Don't know                        72.0
# 21              Permanent                 Yes                        12.0
# 22  Seasonal OR temporary                 Yes                        10.0
# 23  Seasonal OR temporary                 Yes                        30.0
# 24              Permanent                 Yes                        12.0
# 25              Permanent                 Yes                        48.0
# 26              Permanent                 Yes                        48.0
# 27              Permanent                 Yes                        24.0
# 28              Permanent                 Yes                        72.0
# 29              Permanent                 Yes                        36.0
# 30              Permanent                 Yes                         8.0
# 31              Permanent                 Yes                        48.0
# 32              Permanent                 Yes                        29.0
# 33              Permanent                 Yes                        24.0
# 34              Permanent          Don't know                         6.0
# 35              Permanent                 Yes                        32.0
# 36              Permanent                 Yes                        30.0
# 37              Permanent                 Yes                        66.0
# 38              Permanent             Refused                        55.0
# 39              Permanent                 Yes                        84.0
# 40              Permanent                 Yes                        60.0
# 41              Permanent                 Yes                        22.0
# 42              Permanent                 Yes                        24.0
# 43  Seasonal OR temporary                 Yes                         3.0
# 44              Permanent                 Yes                        36.0
#
#                   workplace_satis_core trust_leadership_core  \
# 0                   Somewhat Satisfied                   Yes
# 1                   Somewhat Satisfied                   Yes
# 2                       Very satisfied                   Yes
# 3                       Very satisfied                   Yes
# 4                       Very satisfied                   Yes
# 5                   Somewhat Satisfied                   Yes
# 6                       Very satisfied                   Yes
# 7                   Somewhat Satisfied            Don't know
# 8                       Very satisfied            Don't know
# 9   Neither satisfied nor dissatisfied                   Yes
# 10                  Somewhat Satisfied                   Yes
# 11                      Very satisfied                   Yes
# 12  Neither satisfied nor dissatisfied                   Yes
# 13                  Somewhat Satisfied                   Yes
# 14                  Somewhat Satisfied                   Yes
# 15  Neither satisfied nor dissatisfied                    No
# 16                  Somewhat Satisfied                   Yes
# 17                      Very satisfied                   Yes
# 18                  Somewhat Satisfied                    No
# 19                  Somewhat Satisfied                    No
# 20                      Very satisfied                   Yes
# 21                      Very satisfied                   Yes
# 22                      Very satisfied                   Yes
# 23                      Very satisfied                   Yes
# 24                  Somewhat Satisfied                   Yes
# 25                      Very satisfied                   Yes
# 26                      Very satisfied                   Yes
# 27                      Very satisfied                   Yes
# 28                      Very satisfied                   Yes
# 29                      Very satisfied                   Yes
# 30                  Somewhat Satisfied                   Yes
# 31                  Somewhat Satisfied                   Yes
# 32                      Very satisfied                   Yes
# 33                      Very satisfied                   Yes
# 34                      Very satisfied                   Yes
# 35                      Very satisfied                   Yes
# 36                  Somewhat Satisfied                   Yes
# 37                      Very satisfied                   Yes
# 38                      Very satisfied                   Yes
# 39                  Somewhat Satisfied                   Yes
# 40                  Somewhat Satisfied                   Yes
# 41                      Very satisfied                   Yes
# 42                  Somewhat Satisfied                   Yes
# 43                      Very satisfied                   Yes
# 44                  Somewhat Satisfied                   Yes
#
#    living_wage_tf_core conditions_rate_core         safety_core  \
# 0                   No        Somewhat good      Strongly agree
# 1                   No  Neither good or bad      Strongly agree
# 2                  Yes        Somewhat good      Strongly agree
# 3                  Yes        Somewhat good      Strongly agree
# 4                  Yes  Neither good or bad      Strongly agree
# 5                   No  Neither good or bad      Strongly agree
# 6                  Yes  Neither good or bad      Strongly agree
# 7                   No  Neither good or bad      Somewhat agree
# 8                   No        Somewhat good      Strongly agree
# 9                  Yes  Neither good or bad      Strongly agree
# 10                 Yes            Very good      Strongly agree
# 11                  No        Somewhat good      Somewhat agree
# 12                  No        Somewhat good      Strongly agree
# 13                  No        Somewhat good      Strongly agree
# 14                  No            Very good      Strongly agree
# 15                  No  Neither good or bad  Agree nor disagree
# 16                  No            Very good      Strongly agree
# 17          Don't know            Very good      Strongly agree
# 18                  No        Somewhat good      Strongly agree
# 19                  No  Neither good or bad      Strongly agree
# 20          Don't know        Somewhat good      Somewhat agree
# 21                  No            Very good      Strongly agree
# 22                  No            Very good      Strongly agree
# 23                 Yes        Somewhat good      Somewhat agree
# 24                 Yes        Somewhat good      Strongly agree
# 25                  No            Very good      Strongly agree
# 26                  No        Somewhat good      Strongly agree
# 27                 Yes        Somewhat good      Somewhat agree
# 28                  No  Neither good or bad      Somewhat agree
# 29                  No            Very good      Strongly agree
# 30                 Yes  Neither good or bad      Strongly agree
# 31                 Yes        Somewhat good  Agree nor disagree
# 32                  No            Very good      Strongly agree
# 33                 Yes        Somewhat good      Strongly agree
# 34                 Yes            Very good      Strongly agree
# 35                 Yes            Very good      Strongly agree
# 36                  No        Somewhat good      Strongly agree
# 37                 Yes            Very good      Strongly agree
# 38                  No            Very good      Strongly agree
# 39                 Yes        Somewhat good      Strongly agree
# 40                 Yes            Very good      Strongly agree
# 41                 Yes            Very good      Strongly agree
# 42                  No        Somewhat good      Strongly agree
# 43                 Yes            Very good      Strongly agree
# 44                  No        Somewhat good      Strongly agree
#
#    accident_last_year injury_last_year covid_safety_measures_core  \
# 0                  No              NaN             Strongly Agree
# 1                  No              NaN             Strongly Agree
# 2                  No              NaN             Strongly Agree
# 3                  No              NaN             Strongly Agree
# 4                  No              NaN             Strongly Agree
# 5                  No              NaN             Strongly Agree
# 6                  No              NaN             Strongly Agree
# 7                  No              NaN             Somewhat agree
# 8                  No              NaN             Somewhat agree
# 9                  No              NaN             Strongly Agree
# 10                 No              NaN             Strongly Agree
# 11                Yes       1 occasion             Strongly Agree
# 12                 No              NaN             Strongly Agree
# 13                 No              NaN             Strongly Agree
# 14                 No              NaN             Strongly Agree
# 15                Yes       1 occasion             Somewhat agree
# 16                 No              NaN             Strongly Agree
# 17                 No              NaN             Strongly Agree
# 18                 No              NaN             Strongly Agree
# 19                 No              NaN             Strongly Agree
# 20                 No              NaN             Strongly Agree
# 21                 No              NaN             Strongly Agree
# 22                 No              NaN             Somewhat agree
# 23                 No              NaN             Strongly Agree
# 24                 No              NaN             Strongly Agree
# 25                 No              NaN             Strongly Agree
# 26                 No              NaN             Strongly Agree
# 27                 No              NaN             Strongly Agree
# 28                Yes       1 occasion             Somewhat agree
# 29                 No              NaN             Strongly Agree
# 30                 No              NaN             Strongly Agree
# 31                 No              NaN             Strongly Agree
# 32                 No              NaN             Strongly Agree
# 33                 No              NaN             Somewhat agree
# 34                 No              NaN             Strongly Agree
# 35                 No              NaN             Strongly Agree
# 36                 No              NaN             Strongly Agree
# 37                 No              NaN             Strongly Agree
# 38                 No              NaN                    Refused
# 39                Yes       1 occasion             Strongly Agree
# 40                 No              NaN             Strongly Agree
# 41                 No              NaN             Strongly Agree
# 42                 No              NaN             Strongly Agree
# 43                 No              NaN             Strongly Agree
# 44                 No              NaN             Strongly Agree
#
#    return_next_season_core pressure_to_work_core factory_recommend_tf_core
# 0                      Yes     Strongly disagree                         7
# 1                      Yes     Strongly disagree                         8
# 2                      Yes     Strongly disagree                         8
# 3                      Yes     Strongly disagree                         6
# 4                      Yes     Strongly disagree                         8
# 5               Don't know     Strongly disagree                         8
# 6                      Yes     Strongly disagree                         7
# 7                      Yes    Agree nor disagree                         5
# 8                      Yes    Agree nor disagree                         8
# 9                      Yes     Strongly disagree                        10
# 10                     Yes     Strongly disagree                        10
# 11                     Yes     Strongly disagree                         5
# 12                     Yes     Strongly disagree                         7
# 13                     Yes     Strongly disagree                         9
# 14                     Yes     Strongly disagree                        10
# 15              Don't know               Refused                         5
# 16                     Yes     Strongly disagree                         8
# 17                     Yes     Strongly disagree                         9
# 18                     Yes     Strongly disagree                         9
# 19              Don't know     Strongly disagree                         6
# 20                     Yes     Strongly disagree                         8
# 21                     Yes     Strongly disagree                        10
# 22                     Yes     Strongly disagree                        10
# 23                     Yes        Strongly agree                         6
# 24                     Yes     Strongly disagree                        10
# 25                     Yes     Strongly disagree                        10
# 26                     Yes     Strongly disagree                         9
# 27                     Yes     Strongly disagree                         9
# 28                     Yes     Strongly disagree                        10
# 29                     Yes     Strongly disagree                        10
# 30                     Yes        Strongly agree                        10
# 31                     Yes     Strongly disagree                         8
# 32                     Yes     Strongly disagree                        10
# 33                     Yes     Strongly disagree                         8
# 34                     Yes     Strongly disagree                        10
# 35                     Yes     Strongly disagree                        10
# 36                     Yes     Strongly disagree                         8
# 37                     Yes     Strongly disagree                        10
# 38                     Yes    Agree nor disagree                        10
# 39                     Yes     Strongly disagree                         7
# 40                     Yes     Strongly disagree                        10
# 41                     Yes     Strongly disagree                         9
# 42                     Yes     Strongly disagree                         9
# 43                     Yes     Strongly disagree                        10
# 44                     Yes     Strongly disagree                         6

# %%
# Identify the null rows
fairtrade_df.isnull().sum()
# Out:
# worker_type_core                 0
# understand_contract              5
# entity_tenure_total_months       0
# workplace_satis_core             0
# trust_leadership_core            0
# living_wage_tf_core              0
# conditions_rate_core             0
# safety_core                      0
# accident_last_year               0
# injury_last_year              4320
# covid_safety_measures_core     222
# return_next_season_core        222
# pressure_to_work_core          222
# factory_recommend_tf_core      222
# dtype: int64

# %%
# Drop the null rows 
fairtrade_df.dropna(subset = ['understand_contract','entity_tenure_total_months','covid_safety_measures_core','return_next_season_core','pressure_to_work_core','factory_recommend_tf_core'], inplace=True)
fairtrade_df.isnull().sum()
# Out:
# worker_type_core                 0
# understand_contract              0
# entity_tenure_total_months       0
# workplace_satis_core             0
# trust_leadership_core            0
# living_wage_tf_core              0
# conditions_rate_core             0
# safety_core                      0
# accident_last_year               0
# injury_last_year              4108
# covid_safety_measures_core       0
# return_next_season_core          0
# pressure_to_work_core            0
# factory_recommend_tf_core        0
# dtype: int64

# %%
# Check the datatypes of our columns 
fairtrade_df.dtypes
# Out:
# worker_type_core               object
# understand_contract            object
# entity_tenure_total_months    float64
# workplace_satis_core           object
# trust_leadership_core          object
# living_wage_tf_core            object
# conditions_rate_core           object
# safety_core                    object
# accident_last_year             object
# injury_last_year               object
# covid_safety_measures_core     object
# return_next_season_core        object
# pressure_to_work_core          object
# factory_recommend_tf_core      object
# dtype: object

# %%
# Convert columns to numeric data type
fairtrade_df[["entity_tenure_total_months", "factory_recommend_tf_core"]] = fairtrade_df[["entity_tenure_total_months", "factory_recommend_tf_core"]].apply(pd.to_numeric)
fairtrade_df['entity_tenure_total_months'] = fairtrade_df['entity_tenure_total_months'].astype(int)

fairtrade_df.dtypes
# Out:
# worker_type_core              object
# understand_contract           object
# entity_tenure_total_months     int64
# workplace_satis_core          object
# trust_leadership_core         object
# living_wage_tf_core           object
# conditions_rate_core          object
# safety_core                   object
# accident_last_year            object
# injury_last_year              object
# covid_safety_measures_core    object
# return_next_season_core       object
# pressure_to_work_core         object
# factory_recommend_tf_core      int64
# dtype: object

# %%
# Export the Dataframe as a new CSV file without the index.
fairtrade_df.to_csv("fairtrade_clean_data.csv", index=False)
