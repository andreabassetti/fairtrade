# %%
import numpy as np
import pandas as pd

# %%
# Load the data
fairtrade_data = "IRL_ClassProjectData_220210.xlsx"
fairtrade_df = pd.read_excel(fairtrade_data)
fairtrade_df.head()
# Out:
#   Survey Number        Response ID ch_account_name gender_core  age_core  \
# 0      Survey 2  R_1NsRph9Oqxl6CnG          Farm 1         Man        30
# 1      Survey 2  R_2BlpeLG3DymUC2o          Farm 1       Woman        30
# 2      Survey 2  R_3WMv7jb7gBKEm2t          Farm 1         Man        24
# 3      Survey 2  R_2SBT3CXWOyuor1k          Farm 1         Man        58
# 4      Survey 2  R_OBEgl4lS6LpSkDL          Farm 1         Man        38
#
#   education_level_core worker_type_core understand_contract  \
# 0    Elementary School        Permanent                 Yes
# 1            No school        Permanent                 Yes
# 2        Middle School        Permanent                 Yes
# 3    Elementary School        Permanent                 Yes
# 4        Middle School        Permanent                 Yes
#
#    entity_tenure - Years  entity_tenure - Months  ...  accident_last_year  \
# 0                   11.0                     0.0  ...                  No
# ...

# %%
# Change column names 
fairtrade_df.rename(columns = {'entity_tenure - Years':'entity_tenure_years', 
                               'entity_tenure - Months':'entity_tenure_months'}, inplace = True)

# Drop columns 
fairtrade_df.drop(['Survey Number','Response ID','ch_account_name','gender_core','age_core',
                   'education_level_core','entity_seasons','work_last_season_tf','num_week_income_core_usd',
                   'num_week_income_core_mxn','weeks_per_year','income_change_core','save_money_tf_core',
                   'financial_resilience_core','unsafe_reason_ms_core','management_complaint_treatment_core',
                   'leadership_feedback_core','leadership_satisfaction_core','Unnamed: 33'], axis=1, inplace=True)

fairtrade_df.head(10)
# Out:
#   worker_type_core understand_contract  entity_tenure_years  \
# 0        Permanent                 Yes                 11.0
# 1        Permanent                 Yes                  9.0
# 2        Permanent                 Yes                  5.0
# 3        Permanent                 Yes                  6.0
# 4        Permanent                 Yes                  9.0
# 5        Permanent                 Yes                  9.0
# 6        Permanent                 Yes                  2.0
# 7        Permanent          Don't know                 38.0
# 8        Permanent                 Yes                  7.0
# 9        Permanent                 Yes                  7.0
#
#    entity_tenure_months                workplace_satis_core  \
# 0                   0.0                  Somewhat Satisfied
# 1                   0.0                  Somewhat Satisfied
# 2                   7.0                      Very satisfied
# 3                   7.0                      Very satisfied
# ...

# %%
# Identify the null rows
fairtrade_df.isnull().sum()
# Out:
# worker_type_core                 0
# understand_contract              5
# entity_tenure_years           2962
# entity_tenure_months            15
# workplace_satis_core             0
# trust_leadership_core            0
# living_wage_tf_core              0
# conditions_rate_core             0
# safety_core                      0
# accident_last_year               0
# injury_last_year              4407
# covid_safety_measures_core     222
# return_next_season_core        222
# pressure_to_work_core          222
# factory_recommend_tf_core      222
# dtype: int64

# %%
# Drop the null rows 
fairtrade_df.dropna(subset = ['entity_tenure_years','entity_tenure_months','injury_last_year','covid_safety_measures_core','return_next_season_core','pressure_to_work_core','factory_recommend_tf_core'], inplace=True)
fairtrade_df.isnull().sum()
# Out:
# worker_type_core              0
# understand_contract           0
# entity_tenure_years           0
# entity_tenure_months          0
# workplace_satis_core          0
# trust_leadership_core         0
# living_wage_tf_core           0
# conditions_rate_core          0
# safety_core                   0
# accident_last_year            0
# injury_last_year              0
# covid_safety_measures_core    0
# return_next_season_core       0
# pressure_to_work_core         0
# factory_recommend_tf_core     0
# dtype: int64

# %%
# Check the datatypes of our columns 
fairtrade_df.dtypes
# Out:
# worker_type_core               object
# understand_contract            object
# entity_tenure_years           float64
# entity_tenure_months          float64
# workplace_satis_core           object
# trust_leadership_core          object
# living_wage_tf_core            object
# conditions_rate_core           object
# safety_core                    object
# accident_last_year             object
# injury_last_year               object
# covid_safety_measures_core     object
# return_next_season_core        object
# pressure_to_work_core          object
# factory_recommend_tf_core      object
# dtype: object

# %%
# Drop the rows with 'refused'
fairtrade_df = fairtrade_df[fairtrade_df["understand_contract"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["workplace_satis_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["trust_leadership_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["living_wage_tf_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["conditions_rate_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["safety_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["accident_last_year"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["injury_last_year"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["covid_safety_measures_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["return_next_season_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["pressure_to_work_core"].str.contains("Refused") == False]
fairtrade_df = fairtrade_df[fairtrade_df["factory_recommend_tf_core"].str.contains("Refused") == False]

fairtrade_df.head(10)
# Out:
#           worker_type_core understand_contract  entity_tenure_years  \
# 11               Permanent                 Yes                  2.0
# 28               Permanent                 Yes                  6.0
# 39               Permanent                 Yes                  7.0
# 73   Seasonal OR temporary                 Yes                  0.0
# 75               Permanent                 Yes                  0.0
# 93   Seasonal OR temporary                 Yes                  3.0
# 99               Permanent                 Yes                  3.0
# 100  Seasonal OR temporary                 Yes                  0.0
# 102              Permanent                 Yes                  0.0
# 123              Permanent                 Yes                  0.0
#
#      entity_tenure_months                workplace_satis_core  \
# 11                    4.0                      Very satisfied
# 28                    0.0                      Very satisfied
# ...

# %%
# Replace values in factory_recommend_tf_core column
fairtrade_df['factory_recommend_tf_core'] = fairtrade_df['factory_recommend_tf_core'].replace(['10 - Extremely likely', '5 - Neutral'], ['10','5'], inplace=True)
fairtrade_df.head(30)
# Out:
#           worker_type_core understand_contract  entity_tenure_years  \
# 11               Permanent                 Yes                  2.0
# 28               Permanent                 Yes                  6.0
# 39               Permanent                 Yes                  7.0
# 73   Seasonal OR temporary                 Yes                  0.0
# 75               Permanent                 Yes                  0.0
# 93   Seasonal OR temporary                 Yes                  3.0
# 99               Permanent                 Yes                  3.0
# 100  Seasonal OR temporary                 Yes                  0.0
# 102              Permanent                 Yes                  0.0
# 123              Permanent                 Yes                  0.0
# 136              Permanent                 Yes                  3.0
# 138              Permanent                 Yes                  1.0
# 148              Permanent                 Yes                  0.0
# ...
