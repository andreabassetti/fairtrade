# %%
# Add the Pandas dependency.
import pandas as pd

# %%
# Files to load
cocoa_unclean = "Resources/cocoa_unclean.csv"
cocoa_unclean_df = pd.read_csv(cocoa_unclean,dtype='object')
cocoa_unclean_df.head()
# Out:
#   survey_id survey_year   obs_id start_date end_date duration date  year  age  \
# 0         3           0  y0v1:20        NaN      NaN      NaN  NaN  2013  NaN
# 1         3           0   y0v1:4        NaN      NaN      NaN  NaN  2013  NaN
# 2         3           0  y0v1:21        NaN      NaN      NaN  NaN  2013  NaN
# 3         3           0  y0v1:14        NaN      NaN      NaN  NaN  2013  NaN
# 4         3           0  y0v1:17        NaN      NaN      NaN  NaN  2013  NaN
#
#   gender  ... management_complaint_treatment_core ft_change_core  \
# 0    NaN  ...                                 NaN            NaN
# 1    NaN  ...                                 NaN            NaN
# 2    NaN  ...                                 NaN            NaN
# 3    NaN  ...                                 NaN            NaN
# 4    NaN  ...                                 NaN            NaN
#
#   pp_no_vote_reason_core second_payment second_payment_spending  \
# ...

# %%
list(cocoa_unclean_df)
# Out:
# ['survey_id',
#  'survey_year',
#  'obs_id',
#  'start_date',
#  'end_date',
#  'duration',
#  'date',
#  'year',
#  'age',
#  'gender',
#  'ch_account_name2',
#  'section_name',
#  'last_main_harvest_sales_knowledge',
#  'last_main_harvest_sales_kg',
#  'current_mid_harvest_sales_knowledge',
#  'current_mid_harvest_sales_kg',
#  'area_production_increase_last_harvest',
#  'last_harvest_area_ha',
#  'income_change',
#  'area_production_change_next_harvest',
#  'fertilizer_use_main',
#  'no_fertilizer_use_main',
#  'fertilizer_use_main_timeframe',
#  'fertilizer_use_mid',
#  'no_fertilizer_use_mid',
#  'fertilizer_use_mid_timeframe',
#  'fertilizer_source',
#  'fertilizer_payment',
#  'pesticide_use_tf',
#  'handle_pesticides_tf',
#  'ppe_use_frequency',
#  'ppe_use_type_ms',
#  'ans_ppeuse_boots',
#  'ans_ppeuse_glasses',
#  'ans_ppeuse_gloves',
#  'ans_ppeuse_hat',
#  'ans_ppeuse_mask',
#  'ans_ppeuse_protection-suit',
#  'income_portion',
#  'income_sources_ms',
# ...

# %%
#print(cocoa_unclean_df['survey_id'].value_counts())
print(cocoa_unclean_df['survey_year'].value_counts())
#print(cocoa_unclean_df['obs_id'].value_counts())
#print(cocoa_unclean_df['start_date'].value_counts())
#print(cocoa_unclean_df['end_date'].value_counts())
#print(cocoa_unclean_df['duration'].value_counts())
#print(cocoa_unclean_df['date'].value_counts())
print(cocoa_unclean_df['year'].value_counts())
print(cocoa_unclean_df['age'].value_counts())
print(cocoa_unclean_df['gender'].value_counts())
print(cocoa_unclean_df['ch_account_name2'].value_counts())
print(cocoa_unclean_df['section_name'].value_counts())
print(cocoa_unclean_df['last_main_harvest_sales_knowledge'].value_counts())
print(cocoa_unclean_df['last_main_harvest_sales_kg'].value_counts())
print(cocoa_unclean_df['current_mid_harvest_sales_knowledge'].value_counts())
print(cocoa_unclean_df['current_mid_harvest_sales_kg'].value_counts())
print(cocoa_unclean_df['area_production_increase_last_harvest'].value_counts())
print(cocoa_unclean_df['last_harvest_area_ha'].value_counts())
print(cocoa_unclean_df['income_change'].value_counts())
print(cocoa_unclean_df['area_production_change_next_harvest'].value_counts())
print(cocoa_unclean_df['fertilizer_use_main'].value_counts())
print(cocoa_unclean_df['no_fertilizer_use_main'].value_counts())
print(cocoa_unclean_df['fertilizer_use_main_timeframe'].value_counts())
print(cocoa_unclean_df['fertilizer_use_mid'].value_counts())
print(cocoa_unclean_df['no_fertilizer_use_mid'].value_counts())
print(cocoa_unclean_df['fertilizer_use_mid_timeframe'].value_counts())
print(cocoa_unclean_df['fertilizer_source'].value_counts())
print(cocoa_unclean_df['fertilizer_payment'].value_counts())
print(cocoa_unclean_df['pesticide_use_tf'].value_counts())
print(cocoa_unclean_df['handle_pesticides_tf'].value_counts())
print(cocoa_unclean_df['ppe_use_frequency'].value_counts())
print(cocoa_unclean_df['ppe_use_type_ms'].value_counts())
print(cocoa_unclean_df['ans_ppeuse_boots'].value_counts())
print(cocoa_unclean_df['ans_ppeuse_glasses'].value_counts())
print(cocoa_unclean_df['ans_ppeuse_gloves'].value_counts())
print(cocoa_unclean_df['ans_ppeuse_hat'].value_counts())
print(cocoa_unclean_df['ans_ppeuse_mask'].value_counts())
print(cocoa_unclean_df['ans_ppeuse_protection-suit'].value_counts())
print(cocoa_unclean_df['income_portion'].value_counts())
print(cocoa_unclean_df['income_sources_ms'].value_counts())
print(cocoa_unclean_df['ans_is_vegetable-plantations'].value_counts())
print(cocoa_unclean_df['ans_is_plantation-of-cashew-nut'].value_counts())
print(cocoa_unclean_df['ans_is_plantation-of-palm-oil'].value_counts())
print(cocoa_unclean_df['ans_is_sale-of-wood'].value_counts())
print(cocoa_unclean_df['ans_is_coffee-plantation'].value_counts())
print(cocoa_unclean_df['ans_is_banana-plantation'].value_counts())
print(cocoa_unclean_df['ans_is_rice-plantation'].value_counts())
print(cocoa_unclean_df['ans_is_corn-plantation'].value_counts())
print(cocoa_unclean_df['ans_is_rubber-plantation'].value_counts())
print(cocoa_unclean_df['ans_is_other'].value_counts())
print(cocoa_unclean_df['ans_is_refused'].value_counts())
print(cocoa_unclean_df['food_sources_ms'].value_counts())
print(cocoa_unclean_df['hh_size'].value_counts())
print(cocoa_unclean_df['num_children'].value_counts())
print(cocoa_unclean_df['child_age_1'].value_counts())
print(cocoa_unclean_df['child_age_2'].value_counts())
print(cocoa_unclean_df['child_age_3'].value_counts())
print(cocoa_unclean_df['child_age_4'].value_counts())
print(cocoa_unclean_df['child_age_5'].value_counts())
print(cocoa_unclean_df['child_age_6'].value_counts())
print(cocoa_unclean_df['child_age_7'].value_counts())
print(cocoa_unclean_df['child_age_8'].value_counts())
print(cocoa_unclean_df['child_age_9'].value_counts())
print(cocoa_unclean_df['child_age_10'].value_counts())
print(cocoa_unclean_df['child_age_11'].value_counts())
print(cocoa_unclean_df['child_age_12'].value_counts())
print(cocoa_unclean_df['child_age_13'].value_counts())
print(cocoa_unclean_df['child_age_14'].value_counts())
print(cocoa_unclean_df['child_age_15'].value_counts())
print(cocoa_unclean_df['child_age_16'].value_counts())
print(cocoa_unclean_df['child_age_17'].value_counts())
print(cocoa_unclean_df['child_age_18'].value_counts())
print(cocoa_unclean_df['child_age_19'].value_counts())
print(cocoa_unclean_df['child_age_20'].value_counts())
print(cocoa_unclean_df['child_age_21'].value_counts())
print(cocoa_unclean_df['child_age_22'].value_counts())
print(cocoa_unclean_df['child_age_23'].value_counts())
print(cocoa_unclean_df['child_age_24'].value_counts())
print(cocoa_unclean_df['child_age_25'].value_counts())
print(cocoa_unclean_df['child_age_26'].value_counts())
print(cocoa_unclean_df['child_age_27'].value_counts())
print(cocoa_unclean_df['num_children_age_core - Ages 5-10 (Primary School ) - How many children (age 18 or younger) live in your household?'].value_counts())
print(cocoa_unclean_df['num_children_age_core - Ages 11-18 (Secondary School) - How many children (age 18 or younger) live in your household?'].value_counts())
print(cocoa_unclean_df['Enrollment % '].value_counts())
print(cocoa_unclean_df['child_not_enrolled_ms_core'].value_counts())
print(cocoa_unclean_df['water_access_distance'].value_counts())
print(cocoa_unclean_df['water_source'].value_counts())
print(cocoa_unclean_df['water_sick_tf'].value_counts())
print(cocoa_unclean_df['med_care_access'].value_counts())
print(cocoa_unclean_df['avg_month_meat_meals'].value_counts())
print(cocoa_unclean_df['skip_meals'].value_counts())
print(cocoa_unclean_df['skipmeals_frequency'].value_counts())
print(cocoa_unclean_df['emergency_money_ms'].value_counts())
print(cocoa_unclean_df['ans_em_borrow-from-cooperative'].value_counts())
print(cocoa_unclean_df['ans_em_borrow-from-financial-institution'].value_counts())
print(cocoa_unclean_df['ans_em_borrow-from-friends-family'].value_counts())
print(cocoa_unclean_df['ans_em_government-assistance'].value_counts())
print(cocoa_unclean_df["ans_em_i-don't-know-what-to-do"].value_counts())
print(cocoa_unclean_df['ans_em_insurance-policies'].value_counts())
print(cocoa_unclean_df['ans_em_other'].value_counts())
print(cocoa_unclean_df['ans_em_savings'].value_counts())
print(cocoa_unclean_df['ans_em_received-gift-money'].value_counts())
print(cocoa_unclean_df['children_viability_eng'].value_counts())
print(cocoa_unclean_df['trainings_attended_ms'].value_counts())
print(cocoa_unclean_df['no_training_reason'].value_counts())
print(cocoa_unclean_df['ga_attendance_tf'].value_counts())
print(cocoa_unclean_df['premium_decision_participate'].value_counts())
print(cocoa_unclean_df['premium_vote_cash'].value_counts())
print(cocoa_unclean_df['premium_opinion_consideration'].value_counts())
print(cocoa_unclean_df['premium_satisfaction'].value_counts())
print(cocoa_unclean_df['leadership_feedback'].value_counts())
print(cocoa_unclean_df['leadership_satisfaction'].value_counts())
print(cocoa_unclean_df['no_leadership_feedback_reason'].value_counts())
print(cocoa_unclean_df['children_primary_school'].value_counts())
print(cocoa_unclean_df['children_secondary_school'].value_counts())
print(cocoa_unclean_df['monthly income'].value_counts())
print(cocoa_unclean_df['cocoa_price_good_conditions'].value_counts())
print(cocoa_unclean_df['amount_invest_plantation'].value_counts())
print(cocoa_unclean_df['education_level_core'].value_counts())
print(cocoa_unclean_df['num_children_age_core - Ages 5-10 (Primary School ) - How many children (age 18 or younger) live in your household?2'].value_counts())
print(cocoa_unclean_df['num_children_age_core - Ages 5-10 (Primary School ) - How many of those children are enrolled in school?'].value_counts())
print(cocoa_unclean_df['num_children_age_core - Ages 11-18 (Secondary School) - How many children (age 18 or younger) live in your household?3'].value_counts())
print(cocoa_unclean_df['num_children_age_core - Ages 11-18 (Secondary School) - How many of those children are enrolled in school?'].value_counts())
print(cocoa_unclean_df['entity_tenure - Years'].value_counts())
print(cocoa_unclean_df['entity_tenure - Months'].value_counts())
print(cocoa_unclean_df['coop_leader_tf_core'].value_counts())
print(cocoa_unclean_df['trust_leadership_core'].value_counts())
print(cocoa_unclean_df['fertilizer_type'].value_counts())
print(cocoa_unclean_df['handling_fertilizer_application'].value_counts())
print(cocoa_unclean_df['fertilizer_ppe'].value_counts())
print(cocoa_unclean_df['harvest_change_reason_core - Selected Choice'].value_counts())
print(cocoa_unclean_df['harvest_change_reason_core - Other - Text'].value_counts())
print(cocoa_unclean_df['living_wage_tf_core'].value_counts())
print(cocoa_unclean_df['save_money_tf_core'].value_counts())
print(cocoa_unclean_df['borrow_money_tf_core'].value_counts())
print(cocoa_unclean_df['borrow_source_ms_core'].value_counts())
print(cocoa_unclean_df['financial_resilience_core'].value_counts())
print(cocoa_unclean_df['remittance_tf_core'].value_counts())
print(cocoa_unclean_df['remittance_portion_core'].value_counts())
print(cocoa_unclean_df['hhs_ms_core'].value_counts())
print(cocoa_unclean_df['hhs_resources_frequency_core'].value_counts())
print(cocoa_unclean_df['hhs_sleep_frequency_core'].value_counts())
print(cocoa_unclean_df['hhs_day_frequency_core'].value_counts())
print(cocoa_unclean_df['med_facility_core'].value_counts())
print(cocoa_unclean_df['med_reasons_no_doc_ms_core'].value_counts())
print(cocoa_unclean_df['covid_challenges_ms'].value_counts())
print(cocoa_unclean_df['covid_safety_measures'].value_counts())
print(cocoa_unclean_df['ft_knowledge_core'].value_counts())
print(cocoa_unclean_df['ft_satisfaction_core'].value_counts())
print(cocoa_unclean_df['trust_change_core'].value_counts())
print(cocoa_unclean_df['ftc_suggestion_core'].value_counts())
print(cocoa_unclean_df['management_complaint_treatment_core'].value_counts())
print(cocoa_unclean_df['ft_change_core'].value_counts())
print(cocoa_unclean_df['pp_no_vote_reason_core'].value_counts())
print(cocoa_unclean_df['second_payment'].value_counts())
print(cocoa_unclean_df['second_payment_spending'].value_counts())
print(cocoa_unclean_df['committees_tf_core'].value_counts())
print(cocoa_unclean_df['committees_skills_ms_core'].value_counts())
print(cocoa_unclean_df['ft_benefits_ms_core'].value_counts())
print(cocoa_unclean_df['ft_life_improve_1yr_core'].value_counts())
# Out:
# 2    491
# 9    319
# 0    312
# 5    204
# 1    139
# Name: survey_year, dtype: int64
# 2019    538
# 2017    418
# 2021    408
# 2015    310
# 2014    104
# 2013     95
# Name: year, dtype: int64
# 35    65
# 40    55
# 37    52
# 34    49
# 50    48
#       ..
# 79     1
# 0      1
# 73     1
# 17     1
# 76     1
# Name: age, Length: 61, dtype: int64
# Man      1537
# Woman     135
# Name: gender, dtype: int64
# SOCAHI           329
# CABA             297
# COOPATESA        281
# SCAES            278
# CAABRO           165
# COOP-CA-REFSI    157
# COOPAPEDI        151
# CORES             95
# CAVA              66
# CAEVA             35
# CAET              19
# Name: ch_account_name2, dtype: int64
# Oumé                   118
# HIRE                    81
# Bahé sebon              76
# SINFRA                  67
# Gniti-Touagui           56
#                       ...
# Amanikro                 2
# Doukouya                 1
# Vaou 2 Kouadiobakro      1
# ...

# %%
#renaming values
cocoa_unclean_df['cocoa_price_good_conditions'].replace({"More than 1,500 CFA": "More than 1,300 CFA","1,300-1,500 CFA": "More than 1,300 CFA"}, inplace=True)
print(cocoa_unclean_df['cocoa_price_good_conditions'].value_counts())

cocoa_unclean_df['amount_invest_plantation'].replace({"less than 10,000 CFA": "Less than 10,000 CFA"}, inplace=True)
print(cocoa_unclean_df['amount_invest_plantation'].value_counts())
# Out:
# 900-1,100 CFA          549
# More than 1,300 CFA    228
# 1,100-1,300 CFA        122
# 700-900 CFA             46
# Don't know               1
# Name: cocoa_price_good_conditions, dtype: int64
# More than 100,000 CFA    275
# 100,000 or more CFA      252
# 10,000 - 50,000 CFA      158
# 50,000 - 100,000 CFA     137
# 50,000-100,000 CFA        98
# Less than 10,000 CFA      16
# Don't know                 7
# Refused                    1
# Other                      1
# I dont know                1
# Name: amount_invest_plantation, dtype: int64

# %%
#renaming values
cocoa_unclean_df['income_change'].replace({"This year it increased": "Increased","This year it decreased": "Decreased","No change": "It stayed the same"}, inplace=True)
print(cocoa_unclean_df['income_change'].value_counts())

cocoa_unclean_df['area_production_change_next_harvest'].replace({"It has Increased": "Increase","It has decreased": "Decrease","Stay the same": "It has not changed"}, inplace=True)
print(cocoa_unclean_df['area_production_change_next_harvest'].value_counts())

cocoa_unclean_df['ppe_use_frequency'].replace({"Yes, always": "Always","No, never": "Never"}, inplace=True)
print(cocoa_unclean_df['ppe_use_frequency'].value_counts())

cocoa_unclean_df['income_portion'].replace({"Most": "More than half"}, inplace=True)
print(cocoa_unclean_df['income_portion'].value_counts())

cocoa_unclean_df['water_access_distance'].replace({"> 30": "It takes more than 30 minutes", "I have access to drinking water in my home": "Always available in my house", "It is always available in my house": "Always available in my house", "< 30": "It takes less than 30 minutes", "No access": "I don't have access to potable/drinking water"}, inplace=True)
print(cocoa_unclean_df['water_access_distance'].value_counts())

cocoa_unclean_df['skipmeals_frequency'].replace({"Every 6 months": "At least once every six months", "Every 1-2 months": "At least once every two months", "Every month": "At least once a month", "Every week": "At least once a week"}, inplace=True)
print(cocoa_unclean_df['skipmeals_frequency'].value_counts())

cocoa_unclean_df['children_viability_eng'].replace({"Not sure": "Not Sure"}, inplace=True)
print(cocoa_unclean_df['children_viability_eng'].value_counts())

cocoa_unclean_df['leadership_satisfaction'].replace({"Yes, satisfied": "Somewhat Satisfied", "Yes, very satisfied": "Very satisfied", "No, not satisfied": "Somewhat dissatisfied"}, inplace=True)
print(cocoa_unclean_df['leadership_satisfaction'].value_counts())

cocoa_unclean_df['monthly income'].replace({"Between 0 and 110,000 CFA": "55000", "Between 110,000 and 180,000 CFA": "145000", "Between 180,000 and 350,000 CFA": "265000"}, inplace=True)
print(cocoa_unclean_df['monthly income'].value_counts())
# Out:
# Increased                        601
# Decreased                        501
# It stayed the same                97
# Don't know                        43
# Refused                           22
# I did not plan crop last year      1
# Name: income_change, dtype: int64
# Increase                      763
# It has not changed            526
# Decrease                      470
# Don't know                     13
# I will not plant next year      2
# Name: area_production_change_next_harvest, dtype: int64
# Never                                     210
# Always                                    180
# Sometimes                                  83
# I don't personally apply agrochemicals     73
# Name: ppe_use_frequency, dtype: int64
# More than half     588
# All                355
# More than half     326
# Less than half      77
# Half                17
# I don't know         1
# Name: income_portion, dtype: int64
# I don't have access to potable/drinking water    564
# ...

# %%
list(cocoa_unclean_df)
# Out:
# ['survey_id',
#  'survey_year',
#  'obs_id',
#  'start_date',
#  'end_date',
#  'duration',
#  'date',
#  'year',
#  'age',
#  'gender',
#  'ch_account_name2',
#  'section_name',
#  'last_main_harvest_sales_knowledge',
#  'last_main_harvest_sales_kg',
#  'current_mid_harvest_sales_knowledge',
#  'current_mid_harvest_sales_kg',
#  'area_production_increase_last_harvest',
#  'last_harvest_area_ha',
#  'income_change',
#  'area_production_change_next_harvest',
#  'fertilizer_use_main',
#  'no_fertilizer_use_main',
#  'fertilizer_use_main_timeframe',
#  'fertilizer_use_mid',
#  'no_fertilizer_use_mid',
#  'fertilizer_use_mid_timeframe',
#  'fertilizer_source',
#  'fertilizer_payment',
#  'pesticide_use_tf',
#  'handle_pesticides_tf',
#  'ppe_use_frequency',
#  'ppe_use_type_ms',
#  'ans_ppeuse_boots',
#  'ans_ppeuse_glasses',
#  'ans_ppeuse_gloves',
#  'ans_ppeuse_hat',
#  'ans_ppeuse_mask',
#  'ans_ppeuse_protection-suit',
#  'income_portion',
#  'income_sources_ms',
# ...

# %%
cocoa_unclean_df.to_csv('cocoa_clean.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 cocoa_unclean_df.to_csv('cocoa_clean.csv', index=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3563, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3552 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3554 formatter = DataFrameFormatter(
#    3555     frame=df,
#    3556     header=header,
#    (...)
#    3560     decimal=decimal,
#    3561 )
# -> 3563 return DataFrameRenderer(formatter).to_csv(
#    3564     path_or_buf,
#    3565     line_terminator=line_terminator,
#    3566     sep=sep,
# ...
